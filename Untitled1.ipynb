# %%
import zipfile
import tensorflow as tf
import os
# import  imageio
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# from keras.utils import to_categorical #For keras > 2.0
# import cv2
import scipy.io
from sklearn.model_selection import train_test_split
from keras import initializers
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
import dataframe_image as dfi
import df2img

# %%
mat3 = scipy.io.loadmat('case3_quantum.mat')
mat3_D2_1_2 = scipy.io.loadmat('case3_D2_1_2.mat')
mat3_D2_1_1 = scipy.io.loadmat('case3_D2_1_1.mat')

# %%
ns3 = mat3['ns']
g2_case3 = abs(mat3['g2_a'])
g2_case3 = np.reshape(g2_case3,[1000,1])

# %%
ns3_D2_1_2 = mat3_D2_1_2['ns']
g2_case3_D2_1_2 = mat3_D2_1_2['g2_a']

ns3_D2_1_1 = mat3_D2_1_1['ns']
g2_case3_D2_1_1 = mat3_D2_1_1['g2_a']

# %%
np.shape(g2_case3)
# Out:
# (1000, 1)

# %%
g2_re = []
n_s = []
n_s_D2_1_2 = []
n_s_D2_1_1 = []

for i in range(np.shape(g2_case3)[0]):
    n_s.append(ns3[0][i][0])

for i in range(np.shape(g2_case3_D2_1_2)[0]):
    n_s_D2_1_2.append(ns3_D2_1_2[0][i][0])

for i in range(np.shape(g2_case3_D2_1_1)[0]):
    n_s_D2_1_1.append(ns3_D2_1_1[0][i][0])

# %%
np.shape(g2_case3)[0]
# Out:
# 1000

# %%
np.shape(n_s)
# Out:
# (1000, 40)

# %%
regressor = RandomForestRegressor()
regressor.fit(n_s, g2_case3)
Y_predict_RFR = regressor.predict(n_s_D2_1_1)
# Out:
# C:\Users\kodo0\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
plt.scatter(g2_case3_D2_1_1, Y_predict_RFR)
mean_squared_error(g2_case3_D2_1_1,Y_predict_RFR)
# plt.xlabel("")
# Out:
# 0.05298159816002759

# %%
plt.scatter(g2_case3_D2_1_2, Y_predict_RFR)
mean_squared_error(g2_case3_D2_1_2,Y_predict_RFR)
# Out:
# 0.17753918860508258
